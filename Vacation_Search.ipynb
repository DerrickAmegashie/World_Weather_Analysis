# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps
import numpy as np

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
city_data_df = pd.read_csv("WeatherPy_database.csv")
city_data_df.head()
# Out:
#    City_ID          City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0      Bilibino      RU  68.0546  166.4372      1.81        86
# 1        1  Puerto Ayora      EC  -0.7393  -90.3518     82.40        74
# 2        2        Ixtapa      MX  20.7000 -105.2000     77.00        69
# 3        3     Williston      US  48.1470 -103.6180     68.00        18
# 4        4         Praya      CV  14.9215  -23.5087     69.80        78
#
#    Cloudiness  Wind Speed Current Description
# 0          84        6.67       broken clouds
# 1          20        6.91          few clouds
# 2           1       11.50           clear sky
# 3          30        5.01    scattered clouds
# 4           0       18.41           clear sky

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID             City Country      Lat       Lng  Max Temp  Humidity  \
# 1         1     Puerto Ayora      EC  -0.7393  -90.3518     82.40        74
# 2         2           Ixtapa      MX  20.7000 -105.2000     77.00        69
# 6         6            Natal      BR  -5.7950  -35.2094     82.40        74
# 12       12   Cabo San Lucas      MX  22.8909 -109.9124     82.99        36
# 15       15  Arraial Do Cabo      BR -22.9661  -42.0278     78.80        78
# 18       18          Kahului      US  20.8947 -156.4700     80.60        61
# 19       19             Hilo      US  19.7297 -155.0900     80.60        61
# 21       21        Mahebourg      MU -20.4081   57.7000     78.80        89
# 24       24           Makaha      US  21.4694 -158.2175     84.20        57
# 32       32           Faanui      PF -16.4833 -151.7500     82.62        69
#
#     Cloudiness  Wind Speed   Current Description
# 1           20        6.91            few clouds
# 2            1       11.50             clear sky
# 6           20        9.22            few clouds
# 12          20        9.22            few clouds
# 15          20       23.02            few clouds
# 18          20       21.85            few clouds
# 19           1       12.66  heavy intensity rain
# 21          40        3.44            light rain
# 24           1       12.66             clear sky
# 32          84        8.72         broken clouds

# %%
# 4a. Determine if there are any empty rows.
preferred_cities_df.count()
# Out:
# City_ID                184
# City                   184
# Country                184
# Lat                    184
# Lng                    184
# Max Temp               184
# Humidity               184
# Cloudiness             184
# Wind Speed             184
# Current Description    184
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
preferred_cities_df.dropna()
# Out:
#      City_ID             City Country      Lat       Lng  Max Temp  Humidity  \
# 1          1     Puerto Ayora      EC  -0.7393  -90.3518     82.40        74
# 2          2           Ixtapa      MX  20.7000 -105.2000     77.00        69
# 6          6            Natal      BR  -5.7950  -35.2094     82.40        74
# 12        12   Cabo San Lucas      MX  22.8909 -109.9124     82.99        36
# 15        15  Arraial Do Cabo      BR -22.9661  -42.0278     78.80        78
# ..       ...              ...     ...      ...       ...       ...       ...
# 682      682       Coahuayana      MX  18.7333 -103.6833     86.00        42
# 684      684         Carupano      VE  10.6678  -63.2585     75.61        86
# 693      693        Kaohsiung      TW  22.6163  120.3133     77.00        83
# 698      698      Finschhafen      PG  -6.6024  147.8681     84.29        69
# 700      700       Asamankese      GH   5.8601   -0.6635     84.20        84
#
#      Cloudiness  Wind Speed Current Description
# 1            20        6.91          few clouds
# 2             1       11.50           clear sky
# 6            20        9.22          few clouds
# 12           20        9.22          few clouds
# 15           20       23.02          few clouds
# ..          ...         ...                 ...
# 682          40        7.00    scattered clouds
# 684          89       12.66     overcast clouds
# 693          75        4.61       broken clouds
# 698          77        3.44          light rain
# 700          20        6.91          few clouds
#
# [184 rows x 10 columns]

# %%
clean_df = preferred_cities_df.dropna()
clean_df
# Out:
#      City_ID             City Country      Lat       Lng  Max Temp  Humidity  \
# 1          1     Puerto Ayora      EC  -0.7393  -90.3518     82.40        74
# 2          2           Ixtapa      MX  20.7000 -105.2000     77.00        69
# 6          6            Natal      BR  -5.7950  -35.2094     82.40        74
# 12        12   Cabo San Lucas      MX  22.8909 -109.9124     82.99        36
# 15        15  Arraial Do Cabo      BR -22.9661  -42.0278     78.80        78
# ..       ...              ...     ...      ...       ...       ...       ...
# 682      682       Coahuayana      MX  18.7333 -103.6833     86.00        42
# 684      684         Carupano      VE  10.6678  -63.2585     75.61        86
# 693      693        Kaohsiung      TW  22.6163  120.3133     77.00        83
# 698      698      Finschhafen      PG  -6.6024  147.8681     84.29        69
# 700      700       Asamankese      GH   5.8601   -0.6635     84.20        84
#
#      Cloudiness  Wind Speed Current Description
# 1            20        6.91          few clouds
# 2             1       11.50           clear sky
# 6            20        9.22          few clouds
# 12           20        9.22          few clouds
# 15           20       23.02          few clouds
# ..          ...         ...                 ...
# 682          40        7.00    scattered clouds
# 684          89       12.66     overcast clouds
# 693          75        4.61       broken clouds
# 698          77        3.44          light rain
# 700          20        6.91          few clouds
#
# [184 rows x 10 columns]

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                City Country  Max Temp   Current Description      Lat  \
# 1      Puerto Ayora      EC     82.40            few clouds  -0.7393
# 2            Ixtapa      MX     77.00             clear sky  20.7000
# 6             Natal      BR     82.40            few clouds  -5.7950
# 12   Cabo San Lucas      MX     82.99            few clouds  22.8909
# 15  Arraial Do Cabo      BR     78.80            few clouds -22.9661
# 18          Kahului      US     80.60            few clouds  20.8947
# 19             Hilo      US     80.60  heavy intensity rain  19.7297
# 21        Mahebourg      MU     78.80            light rain -20.4081
# 24           Makaha      US     84.20             clear sky  21.4694
# 32           Faanui      PF     82.62         broken clouds -16.4833
#
#          Lng Hotel Name
# 1   -90.3518
# 2  -105.2000
# 6   -35.2094
# 12 -109.9124
# 15  -42.0278
# 18 -156.4700
# 19 -155.0900
# 21   57.7000
# 24 -158.2175
# 32 -151.7500

# %%
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # 6c. Get latitude and longitude from DataFrame
    params["location"] = f"{lat},{lng}"
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json()
    
hotels
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 5.8431958, 'lng': -0.6456957000000001},
#     'viewport': {'northeast': {'lat': 5.844429430291502,
#       'lng': -0.6444561197084979},
#      'southwest': {'lat': 5.841731469708498, 'lng': -0.647154080291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Juniel lodge',
#    'photos': [{'height': 3120,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103936580731895888844">Enoch Mensah</a>'],
#      'photo_reference': 'ATtYBwKQlN27swaT7b1iF_O3KIaXkoKkZKaqiBfHm6FlnhH1qzrDgCoRZWvbSzu2c-yZ-SxCWmeR6nMbwYa0-3xBMBmDDGKl87sHXEjqDMOq2QM8OZ6QgtG1CIAjnXCwAKM9yvbr7rIpQSOvxaYUSiue-uaTkAJtBnD0byA8EBw5xCoBVtOT',
#      'width': 4160}],
#    'place_id': 'ChIJszsw7HX93g8R7HBqer281nI',
#    'plus_code': {'compound_code': 'R9V3+7P Asamankese, Ghana',
#     'global_code': '6CQXR9V3+7P'},
#    'rating': 3.8,
#    'reference': 'ChIJszsw7HX93g8R7HBqer281nI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 38,
#    'vicinity': 'Behind Engen Filling Station, Asamankese'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 5.8607314, 'lng': -0.6676865000000001},
#     'viewport': {'northeast': {'lat': 5.862005280291503,
#       'lng': -0.666383519708498},
#      'southwest': {'lat': 5.859307319708498, 'lng': -0.669081480291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hotel Rydders',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1728,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100674666711271651431">Hotel Rydders</a>'],
#      'photo_reference': 'ATtYBwIrnQrnW4wUqE5iNfmQtgrzgAiBxkBpmP5geGZF8OZMEruuqAmUhdSNCpRU4Ylrvfk_1ccRK6p25RdkcbBWPrDQK_GAZjDhYjbxYd7mI88Z1-by7HJNb48mUxfuyNGPe0Mz812HXw0hgrP3SRAdtM607uDbOXTOxtcPsAE7X_NDsdYB',
#      'width': 3072}],
#    'place_id': 'ChIJmZM-gLv93g8RC71vdPz2Sjo',
#    'plus_code': {'compound_code': 'V86J+7W Asamankese, Ghana',
#     'global_code': '6CQXV86J+7W'},
#    'rating': 4.3,
#    'reference': 'ChIJmZM-gLv93g8RC71vdPz2Sjo',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 9,
#    'vicinity': 'Estate, Asamankese'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 5.8551043, 'lng': -0.6653257999999999},
#     'viewport': {'northeast': {'lat': 5.856427280291502,
#       'lng': -0.6637384197084979},
#      'southwest': {'lat': 5.853729319708497, 'lng': -0.666436380291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Golden Palace Hotel Ltd',
#    'photos': [{'height': 720,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112311828546840004171">derby Justice</a>'],
#      'photo_reference': 'ATtYBwKAL-4j4rb_SLpAZUv8gDmzCU7OoKQXIXegKVfR47bhIuvFclJ6e-Zbngxu1VzDyrGKW4AbihC94bpk9hQC5KKfwdnrHbOxXfONxG9oOFY2hmRigCEhzNRIZ6fj8Gv_bOgL8Ew9qGLPhMJR6qpgukV7LQKh2pWGaCv9Al0LuqBa0_uD',
#      'width': 1280}],
#    'place_id': 'ChIJeX-HYWL83g8RkWXtQkKqih4',
#    'plus_code': {'compound_code': 'V84M+2V Asamankese, Ghana',
#     'global_code': '6CQXV84M+2V'},
#    'rating': 3.3,
#    'reference': 'ChIJeX-HYWL83g8RkWXtQkKqih4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 49,
#    'vicinity': 'Asamankese- James Town, James Town'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 5.858460099999999, 'lng': -0.6692306},
#     'viewport': {'northeast': {'lat': 5.859824180291501,
#       'lng': -0.6678812697084979},
#      'southwest': {'lat': 5.857126219708497, 'lng': -0.670579230291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Auntie Serwaa Hotel',
#    'photos': [{'height': 1200,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103702892339622580041">richmond amoah kwakye</a>'],
#      'photo_reference': 'ATtYBwLJGet9J7F_PXQwNLGKiP8Q0KS2oE6inU-_55sR9UI37I6thjbtuMjKvrYoNL-2CgCKUV-EU8RKGk5p_1w_e0FRa9nt5MUPaoGvwITsqn1pr_2JqPeuFnBhXdgxWQHUTiXTgyaIt5KbxuXkG1cm-tPwBx0pRctuTAYJ8JjGxYiTi8qp',
#      'width': 1600}],
#    'place_id': 'ChIJ5_CqRo_83g8R5WEHkA5Rf-8',
#    'plus_code': {'compound_code': 'V85J+98 Asamankese, Ghana',
#     'global_code': '6CQXV85J+98'},
#    'rating': 2.9,
#    'reference': 'ChIJ5_CqRo_83g8R5WEHkA5Rf-8',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 38,
#    'vicinity': 'beposo, Asamankese'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 5.855381599999999, 'lng': -0.6590751},
#     'viewport': {'northeast': {'lat': 5.856757830291501,
#       'lng': -0.657666669708498},
#      'southwest': {'lat': 5.854059869708497, 'lng': -0.660364630291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'FIRST STOP HOTEL',
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100505258986325589189">PAKO RABANNI</a>'],
#      'photo_reference': 'ATtYBwLW_a7r5EET-VbMfAhVhdJfqyhzcZvqbTap2zEBnOnRLcb_O2RXtsF1kpCvxj71nLm5c59htFG8Us-NNq3RyH_69XZPLMbzWe6xWAXHxhidjVCKtqQ4TG1sewCMSow7CjwIfLRgAN7uukLQutEX-RqxP5C-tTlEKPembSmTGVWLurbl',
#      'width': 1920}],
#    'place_id': 'ChIJ__uJEGD83g8RDXzLl84K-Bc',
#    'plus_code': {'compound_code': 'V84R+59 Asamankese, Ghana',
#     'global_code': '6CQXV84R+59'},
#    'rating': 3.3,
#    'reference': 'ChIJ__uJEGD83g8RDXzLl84K-Bc',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 121,
#    'vicinity': 'Nsawam Road, Medie'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 5.861367699999999, 'lng': -0.6532889},
#     'viewport': {'northeast': {'lat': 5.862693430291502,
#       'lng': -0.651936319708498},
#      'southwest': {'lat': 5.859995469708497, 'lng': -0.6546342802915021}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Honourable Bruce house',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1200,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115900624708098354501">Samuel Bruce</a>'],
#      'photo_reference': 'ATtYBwJpw5Ibvi_iiYMJ15XKdbeGBf3QRBgiHKp528D_0UktgfRiO3OcCRHi3JZL_lL-Ycp2i1ExZjpSLrc4Q2AGXq6D17sQ6XXFpJENBhPwM2DVzOI11gDpLh-Idk-gqSLrq8BKw-f9k8g6cMcOMg-BlfGDo1K1X6tzyrrHnoeRY-UqhAWI',
#      'width': 1200}],
#    'place_id': 'ChIJYWtm2Sz93g8R_YEkzTMFsdk',
#    'plus_code': {'compound_code': 'V86W+GM Asamankese, Ghana',
#     'global_code': '6CQXV86W+GM'},
#    'rating': 2.3,
#    'reference': 'ChIJYWtm2Sz93g8R_YEkzTMFsdk',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 3,
#    'vicinity': 'Unnamed Road, Asamankese'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 5.862788500000001,
#      'lng': -0.6535587999999999},
#     'viewport': {'northeast': {'lat': 5.864155730291503,
#       'lng': -0.652122319708498},
#      'southwest': {'lat': 5.861457769708498, 'lng': -0.6548202802915021}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Owusuwaa Royal Lodge',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2468,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107562760103776809949">David Kwakye</a>'],
#      'photo_reference': 'ATtYBwJ8aNxbAZ-9l8vpviiNlBdpj_Xh73Lsf4I-fNnwIgDtCpXxHPA4TN7zluj2TwwwxcJIbU9JKrwOmhI9Telrmc7K__ipheLcO-6cBpdf0CBgLn24sLqaMvWd_b51V5MURHVOswsTy5R9T7_9wgZtNQHE07A5TkVhqoVntbp9R375pj8F',
#      'width': 3291}],
#    'place_id': 'ChIJuaIiYPH83g8R1aEREqY6QG0',
#    'plus_code': {'compound_code': 'V87W+4H Asamankese, Ghana',
#     'global_code': '6CQXV87W+4H'},
#    'rating': 3.5,
#    'reference': 'ChIJuaIiYPH83g8R1aEREqY6QG0',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 97,
#    'vicinity': 'Asamankese'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 5.863308, 'lng': -0.653478},
#     'viewport': {'northeast': {'lat': 5.864654930291502,
#       'lng': -0.6521418197084979},
#      'southwest': {'lat': 5.861956969708498, 'lng': -0.654839780291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Owusua Royal Lodge',
#    'photos': [{'height': 2816,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103672573187116452564">richybwoy doki</a>'],
#      'photo_reference': 'ATtYBwKmJFro2AelUBX3AFzHS9jJP7Ei3Wk3l0OApM61txSHdXjxEeFLXyLWchbTIbdXrLFLGVHfsBFfyy-PVJMXkipP0RoEBt4lQTJxwddUKbgzbB4DFWM4BFuY9F3XmlUazac-bzmODxXnKLgwcXBBmvCy7QNgbQfPkkTbNxI4gmf_VJLC',
#      'width': 2112}],
#    'place_id': 'ChIJHT3JoAr93g8RTVa7ZN0tIeY',
#    'plus_code': {'compound_code': 'V87W+8J Asamankese, Ghana',
#     'global_code': '6CQXV87W+8J'},
#    'rating': 3.9,
#    'reference': 'ChIJHT3JoAr93g8RTVa7ZN0tIeY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 31,
#    'vicinity': 'Asamankese'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 5.864900999999999,
#      'lng': -0.6521415999999999},
#     'viewport': {'northeast': {'lat': 5.866226830291501,
#       'lng': -0.650791219708498},
#      'southwest': {'lat': 5.863528869708498, 'lng': -0.653489180291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'AWO GYAMEA MEMORIAL GUEST HOUSE',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 607,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100424234311291489044">AWO GYAMEA MEMORIAL GUEST HOUSE</a>'],
#      'photo_reference': 'ATtYBwKdWrSUuLxCqRs3UD75224PUast7CNSQRSL7TXWK_kaK0p4qCTuARdFknJELYLGcWASBzll03bRDaPfQl0W2cpsb0ADx3KvsBErSEUmSV5OuxlNQC_XULOZFcWlGQf5lAAD44hcmIp38YVwFxWC1lSeSLqPaH7lDtTu8ub_47foUC0x',
#      'width': 1080}],
#    'place_id': 'ChIJffZsy0P93g8RpJnTAKK6Wc4',
#    'plus_code': {'compound_code': 'V87X+X4 Asamankese, Ghana',
#     'global_code': '6CQXV87X+X4'},
#    'rating': 3.3,
#    'reference': 'ChIJffZsy0P93g8RpJnTAKK6Wc4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 3,
#    'vicinity': 'EW-0050-0936, Asamankese'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 5.85281, 'lng': -0.6734366},
#     'viewport': {'northeast': {'lat': 5.854182730291503,
#       'lng': -0.672066919708498},
#      'southwest': {'lat': 5.851484769708499, 'lng': -0.6747648802915021}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hotel Rydders',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106490596248605822315">Hotel Rydders</a>'],
#      'photo_reference': 'ATtYBwLry4l_PQedLLJDKOSwbeTvVxEvawUA8Qj6PWo0zXS-e85pc_oPjn8p5nZSDxummTk0JGpp3iUi6VRi2tCDd1ET9BzIux-nPgVIpNmJVL-hqiypqNB3209Zwfc9f6Jzq6m_nCMXSZQP6XHq_hDAQSkoiPTpJZRtDY95oT5M7Wq1UkE8',
#      'width': 810}],
#    'place_id': 'ChIJn64cdwP93g8RQmWzzNFvaAw',
#    'plus_code': {'compound_code': 'V83G+4J Asamankese, Ghana',
#     'global_code': '6CQXV83G+4J'},
#    'rating': 5,
#    'reference': 'ChIJn64cdwP93g8RQmWzzNFvaAw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'Box As 307, Asamankese'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 5.8650495, 'lng': -0.6520457},
#     'viewport': {'northeast': {'lat': 5.866331480291503,
#       'lng': -0.650692719708498},
#      'southwest': {'lat': 5.863633519708499, 'lng': -0.653390680291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Be you hotel',
#    'place_id': 'ChIJ7yeCQbr93g8Rd2agoRV5JPs',
#    'plus_code': {'compound_code': 'V88X+25 Asamankese, Ghana',
#     'global_code': '6CQXV88X+25'},
#    'rating': 3,
#    'reference': 'ChIJ7yeCQbr93g8Rd2agoRV5JPs',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 4,
#    'vicinity': 'Unnamed Road, Asamankese'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 5.848744099999999, 'lng': -0.6518967},
#     'viewport': {'northeast': {'lat': 5.850041630291502,
#       'lng': -0.650596369708498},
#      'southwest': {'lat': 5.847343669708497, 'lng': -0.6532943302915021}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': '1st Stop Hotel',
#    'photos': [{'height': 3120,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103936580731895888844">Enoch Mensah</a>'],
#      'photo_reference': 'ATtYBwJl4UsmHaLWYoopJU3WC1pcz1SNhC_TyHEY_KjczelgqLGVUdFiFnuJB7xe1PXv7C5cxuQzjyyeiNfwzRauj3ym2Z02_EUEUfWnutAEhQ7smIEHLL11h_RXxCJgTQdeCnCy6lXWkZ_N4Wdm-1iXzICG4falgijbIx0b6isFzXe00vFZ',
#      'width': 4160}],
#    'place_id': 'ChIJdwcTpVv83g8RUzgMkTi0HgU',
#    'plus_code': {'compound_code': 'R8XX+F6 Asamankese, Ghana',
#     'global_code': '6CQXR8XX+F6'},
#    'rating': 3.5,
#    'reference': 'ChIJdwcTpVv83g8RUzgMkTi0HgU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 140,
#    'vicinity': ''},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 5.8519768, 'lng': -0.6492544},
#     'viewport': {'northeast': {'lat': 5.853121930291501,
#       'lng': -0.6480117697084979},
#      'southwest': {'lat': 5.850423969708498, 'lng': -0.650709730291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Palimen Guesthouse',
#    'place_id': 'ChIJrT7j5ln83g8RjPCjwue9XJo',
#    'plus_code': {'compound_code': 'V922+Q7 Asamankese, Ghana',
#     'global_code': '6CQXV922+Q7'},
#    'rating': 5,
#    'reference': 'ChIJrT7j5ln83g8RjPCjwue9XJo',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'Near the Asamankese Police Barrier, Asamankese'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 5.8519768, 'lng': -0.6492543},
#     'viewport': {'northeast': {'lat': 5.853121930291501,
#       'lng': -0.6480116697084979},
#      'southwest': {'lat': 5.850423969708498, 'lng': -0.650709630291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'B. You Hotel',
#    'place_id': 'ChIJrz7j5ln83g8RHOqG4kz7-Hk',
#    'plus_code': {'compound_code': 'V922+Q7 Asamankese, Ghana',
#     'global_code': '6CQXV922+Q7'},
#    'rating': 3.5,
#    'reference': 'ChIJrz7j5ln83g8RHOqG4kz7-Hk',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 4,
#    'vicinity': 'Yayo Junction, Asamankese'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 5.845527099999999, 'lng': -0.6463457},
#     'viewport': {'northeast': {'lat': 5.8469328302915,
#       'lng': -0.645056269708498},
#      'southwest': {'lat': 5.844234869708496, 'lng': -0.6477542302915021}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Yayo Hotel Asamankese',
#    'place_id': 'ChIJRd133k_83g8RxB3XxnXUcYk',
#    'plus_code': {'compound_code': 'R9W3+6F Asamankese, Ghana',
#     'global_code': '6CQXR9W3+6F'},
#    'rating': 3.1,
#    'reference': 'ChIJRd133k_83g8RxB3XxnXUcYk',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 26,
#    'vicinity': 'Juaso - Nsawam Road'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 5.84683, 'lng': -0.685168},
#     'viewport': {'northeast': {'lat': 5.848142780291503,
#       'lng': -0.683537719708498},
#      'southwest': {'lat': 5.845444819708498, 'lng': -0.6862356802915021}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Aboagye Boye Lodge',
#    'place_id': 'ChIJgw3VbIX73g8Rd8NrmjTIiAA',
#    'plus_code': {'compound_code': 'R8W7+PW Asamankese, Ghana',
#     'global_code': '6CQXR8W7+PW'},
#    'reference': 'ChIJgw3VbIX73g8Rd8NrmjTIiAA',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Asamankese off Brewbeat Restaurant, Asamankese'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 5.8442053, 'lng': -0.6427957},
#     'viewport': {'northeast': {'lat': 5.845485680291501,
#       'lng': -0.641601819708498},
#      'southwest': {'lat': 5.842787719708498, 'lng': -0.644299780291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Louis Hotel',
#    'photos': [{'height': 1303,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104563295505828273537">Louis Kwakye</a>'],
#      'photo_reference': 'ATtYBwIDXPnTc7gjdIvMYt9GGHJTapATB65sREViXxbKrZu1axC_2I8nEJFQpPj2nwcnToXfRSAVKK4FPs5Jayd2I1zqiCAMKVpkhlqZMMfGp-em9TMrqkTBmGi1xkFla0Ngg41qMYFH2Uuh9bSIdR4f2FUeGMY16HlyettfGhKVytrwybN7',
#      'width': 714}],
#    'place_id': 'ChIJxwnOv0383g8RQfkT_88zehI',
#    'plus_code': {'compound_code': 'R9V4+MV Asamankese, Ghana',
#     'global_code': '6CQXR9V4+MV'},
#    'rating': 3,
#    'reference': 'ChIJxwnOv0383g8RQfkT_88zehI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 5,
#    'vicinity': ''}],
#  'status': 'OK'}

# %%
len(hotels["results"])
# Out:
# 17

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row['Lat']
    lng = row['Lng']

    # 6c. Get latitude and longitude from DataFrame
    params["location"] = f"{lat},{lng}"
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json()
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError): 
        print("No hotel found...skipping.")
# Out:
# No hotel found...skipping.
# No hotel found...skipping.
# No hotel found...skipping.
# No hotel found...skipping.
# No hotel found...skipping.
# No hotel found...skipping.
# No hotel found...skipping.
# No hotel found...skipping.
# No hotel found...skipping.
# No hotel found...skipping.
# No hotel found...skipping.
# No hotel found...skipping.
# No hotel found...skipping.
# No hotel found...skipping.
# No hotel found...skipping.
# No hotel found...skipping.

# %%
hotel_df
# Out:
#                 City Country  Max Temp Current Description      Lat       Lng  \
# 1       Puerto Ayora      EC     82.40          few clouds  -0.7393  -90.3518
# 2             Ixtapa      MX     77.00           clear sky  20.7000 -105.2000
# 6              Natal      BR     82.40          few clouds  -5.7950  -35.2094
# 12    Cabo San Lucas      MX     82.99          few clouds  22.8909 -109.9124
# 15   Arraial Do Cabo      BR     78.80          few clouds -22.9661  -42.0278
# ..               ...     ...       ...                 ...      ...       ...
# 682       Coahuayana      MX     86.00    scattered clouds  18.7333 -103.6833
# 684         Carupano      VE     75.61     overcast clouds  10.6678  -63.2585
# 693        Kaohsiung      TW     77.00       broken clouds  22.6163  120.3133
# 698      Finschhafen      PG     84.29          light rain  -6.6024  147.8681
# 700       Asamankese      GH     84.20          few clouds   5.8601   -0.6635
#
#                             Hotel Name
# 1            Finch Bay Galapagos Hotel
# 2              Hotel Plaza Providencia
# 6             Villa Park Hotel | Natal
# 12              Hotel Tesoro Los Cabos
# 15                 Pousada Porto Praia
# ..                                 ...
# 682  El rranchito michuacan de ocampos
# 684                    Hotel La dorada
# 693                     Kindness Hotel
# 698                 Cossam Guest House
# 700                       Juniel lodge
#
# [184 rows x 7 columns]

# %%
hotel_df.count()
# Out:
# City                   184
# Country                184
# Max Temp               184
# Current Description    184
# Lat                    184
# Lng                    184
# Hotel Name             184
# dtype: int64

# %%
# Create the output file (CSV).
output_data_file = "hotel.csv"
# Export the City_Data into a CSV.
hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
new_hotel_df = pd.read_csv("hotel.csv")
new_hotel_df
# Out:
#      City_ID             City Country  Max Temp Current Description      Lat  \
# 0          1     Puerto Ayora      EC     82.40          few clouds  -0.7393
# 1          2           Ixtapa      MX     77.00           clear sky  20.7000
# 2          6            Natal      BR     82.40          few clouds  -5.7950
# 3         12   Cabo San Lucas      MX     82.99          few clouds  22.8909
# 4         15  Arraial Do Cabo      BR     78.80          few clouds -22.9661
# ..       ...              ...     ...       ...                 ...      ...
# 179      682       Coahuayana      MX     86.00    scattered clouds  18.7333
# 180      684         Carupano      VE     75.61     overcast clouds  10.6678
# 181      693        Kaohsiung      TW     77.00       broken clouds  22.6163
# 182      698      Finschhafen      PG     84.29          light rain  -6.6024
# 183      700       Asamankese      GH     84.20          few clouds   5.8601
#
#           Lng                         Hotel Name
# 0    -90.3518          Finch Bay Galapagos Hotel
# 1   -105.2000            Hotel Plaza Providencia
# 2    -35.2094           Villa Park Hotel | Natal
# 3   -109.9124             Hotel Tesoro Los Cabos
# 4    -42.0278                Pousada Porto Praia
# ..        ...                                ...
# 179 -103.6833  El rranchito michuacan de ocampos
# 180  -63.2585                    Hotel La dorada
# 181  120.3133                     Kindness Hotel
# 182  147.8681                 Cossam Guest House
# 183   -0.6635                       Juniel lodge
#
# [184 rows x 8 columns]

# %%
# 7. Drop the rows where there is no Hotel Name.
clean_hotel_df = new_hotel_df.dropna()
clean_hotel_df
# Out:
#      City_ID             City Country  Max Temp Current Description      Lat  \
# 0          1     Puerto Ayora      EC     82.40          few clouds  -0.7393
# 1          2           Ixtapa      MX     77.00           clear sky  20.7000
# 2          6            Natal      BR     82.40          few clouds  -5.7950
# 3         12   Cabo San Lucas      MX     82.99          few clouds  22.8909
# 4         15  Arraial Do Cabo      BR     78.80          few clouds -22.9661
# ..       ...              ...     ...       ...                 ...      ...
# 179      682       Coahuayana      MX     86.00    scattered clouds  18.7333
# 180      684         Carupano      VE     75.61     overcast clouds  10.6678
# 181      693        Kaohsiung      TW     77.00       broken clouds  22.6163
# 182      698      Finschhafen      PG     84.29          light rain  -6.6024
# 183      700       Asamankese      GH     84.20          few clouds   5.8601
#
#           Lng                         Hotel Name
# 0    -90.3518          Finch Bay Galapagos Hotel
# 1   -105.2000            Hotel Plaza Providencia
# 2    -35.2094           Villa Park Hotel | Natal
# 3   -109.9124             Hotel Tesoro Los Cabos
# 4    -42.0278                Pousada Porto Praia
# ..        ...                                ...
# 179 -103.6833  El rranchito michuacan de ocampos
# 180  -63.2585                    Hotel La dorada
# 181  120.3133                     Kindness Hotel
# 182  147.8681                 Cossam Guest House
# 183   -0.6635                       Juniel lodge
#
# [168 rows x 8 columns]

# %%
# 8a. Create the output File (CSV)
output_data_file = "WeatherPy_vacation.csv"
# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd{Current Description}<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
locations = clean_hotel_df[["Lat", "Lng"]]
max_temp = clean_hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
