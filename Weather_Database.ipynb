# %%
city_data = []

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
print(coordinates)
# Out:
# [(75.42520933447003, 165.35463481552864), (-5.526646754896447, -102.77614279504071), (10.633446603088387, -105.27360062723652), (47.95367714156572, -103.31766944253596), (-10.471756449923532, 116.56372196352925), (60.926983816005446, -173.76511516701393), (-56.020040386712964, 55.1322833897712), (-3.4300947544996774, -27.94673510498143), (-77.76239171977012, -70.19941504385906), (66.00006857764052, 143.72277030648138), (23.397283190033107, -114.01504740505109), (-36.64165875755704, 2.2228124608011512), (86.00550498640459, -43.81685618774941), (40.12323523683983, -117.04299047152153), (12.567574099603974, -122.60965221585505), (61.82937339161563, -143.9258485866511), (43.406100952132874, -139.59450426629488), (-33.786359655628615, -38.69973642036305), (45.681418893691216, -76.5245224425601), (75.28039494820672, -136.88910325989767), (26.543704557527235, -153.44947868810635), (50.72439979760327, 106.78040167763544), (19.304429792684886, -134.8496915414183), (-67.58768947061222, 111.91384539096953), (-47.16058087556865, 76.79406979413528), (-52.30414442570982, -97.02011335726328), (78.6464264465182, -11.989827668702333), (71.13324402386255, 130.92017339662988), (21.230876431425543, -159.00035967206836), (-32.43926138266354, -63.26054251083637), (55.91754380943257, 35.805773387958936), (-52.108995515239826, -93.40416212317581), (55.56163252409124, 77.58432906375509), (60.785116991191444, -131.56135566629743), (-57.33373012345587, 162.89035474622267), (-49.1124966533783, -55.01783989076057), (-71.05082773483495, -156.62989308872946), (56.57351835390199, -167.99338062772944), (-4.013907697174801, -155.80999028672255), (35.614666973675156, 44.30216793147363), (-7.868224062509995, 45.441147763782624), (85.86221046654583, 64.17794503037825), (-75.48408878330865, 30.592406555071193), (-34.643013107039586, -62.308141151835656), (-32.458578298114304, -103.31980414518092), (-46.658321756684366, -86.52510150822064), (-75.90003810127197, 151.6683610609441), (70.02554736875436, -67.214209483695), (11.061021456963573, 133.74887935472526), (-58.29053059839953, -38.29212814210052), (7.966244438377771, -62.1040392790113), (59.841921108258504, 39.82127709915039), (-22.12286375333892, -19.16443756266466), (-50.48182020182647, -25.650808323603144), (79.3968595026688, 30.343657422945512), (7.26252660203285, 150.09178756715494), (44.154282924665296, -86.55772033430215), (-56.909611733805114, -36.71421652498677), (-45.08281051870911, 59.154380970103915), (28.209860878780148, -94.41640246727198), (58.27462248630553, -121.50815390596648), (15.151112748303532, -9.8605696874165), (63.08051609591044, -1.4955744342609592), (43.649174528128896, 96.38087087291979), (-0.701017241994208, 8.282502848873548), (-69.11260150064263, -31.889142188728243), (67.81361598403277, -132.19086823877709), (83.05151578699369, 4.994148867992351), (83.35673516056951, -89.45936989509313), (40.85028273261534, 122.2051286899798), (-11.795825983033808, 34.42539026330866), (30.02093284684905, 81.61303017693518), (72.65361013528033, 50.43342774199482), (43.42304825759669, -26.384355543185876), (17.787463025629776, -178.09218872714743), (27.306343702722174, 14.82535386069216), (52.86268336547846, 68.73843604984773), (84.77062591446554, -73.12764823673463), (42.02956207250489, -6.646210535593184), (-50.211915566091164, 16.45152538439561), (-77.3872211471226, -164.82698895114765), (-60.37476110208533, -148.8688511340277), (11.040051034595308, 156.7888622982041), (24.42804437626623, 124.9742901698229), (-2.54712601061388, -111.84548827921357), (73.32390790630686, -178.81142900595972), (72.21729873141302, 94.7329154365346), (86.30807555802718, -66.94630720520959), (73.12943145948557, -153.8543563534823), (19.54256174053981, -115.00545121970738), (30.355201154181927, 167.83995074174686), (30.571885420968414, -128.9365936598653), (27.504450604812746, -166.9402682650541), (-21.637492966601357, 20.359064510274095), (-40.467999464485956, -124.06984820759094), (-72.19254766150395, 161.68494267256 ...

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a3a1bbf3a006a03e7fa2120b956d9110

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" +"Alexandria"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a3a1bbf3a006a03e7fa2120b956d9110&q=Alexandria

# %%
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bilibino
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | ixtapa
# Processing Record 4 of Set 1 | williston
# Processing Record 5 of Set 1 | praya
# Processing Record 6 of Set 1 | provideniya
# Processing Record 7 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 1 | natal
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 11 of Set 1 | constitucion
# Processing Record 12 of Set 1 | saldanha
# Processing Record 13 of Set 1 | upernavik
# Processing Record 14 of Set 1 | winnemucca
# Processing Record 15 of Set 1 | cabo san lucas
# Processing Record 16 of Set 1 | fairbanks
# Processing Record 17 of Set 1 | port hardy
# Processing Record 18 of Set 1 | arraial do cabo
# Processing Record 19 of Set 1 | shawville
# Processing Record 20 of Set 1 | tuktoyaktuk
# Processing Record 21 of Set 1 | kahului
# Processing Record 22 of Set 1 | chikoy
# City not found. Skipping...
# Processing Record 23 of Set 1 | hilo
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | mahebourg
# Processing Record 26 of Set 1 | castro
# Processing Record 27 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 1 | tiksi
# Processing Record 29 of Set 1 | makaha
# Processing Record 30 of Set 1 | villa maria
# Processing Record 31 of Set 1 | privokzalnyy
# City not found. Skipping...
# Processing Record 32 of Set 1 | barabinsk
# Processing Record 33 of Set 1 | whitehorse
# Processing Record 34 of Set 1 | bluff
# Processing Record 35 of Set 1 | necochea
# Processing Record 36 of Set 1 | mataura
# Processing Record 37 of Set 1 | bethel
# Processing Record 38 of Set 1 | faanui
# Processing Record 39 of Set 1 | kirkuk
# Processing Record 40 of Set 1 | mitsamiouli
# Processing Record 41 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 1 | port elizabeth
# Processing Record 43 of Set 1 | lincoln
# Processing Record 44 of Set 1 | lebu
# Processing Record 45 of Set 1 | hobart
# Processing Record 46 of Set 1 | clyde river
# Processing Record 47 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 48 of Set 1 | mar del plata
# Processing Record 49 of Set 1 | upata
# Processing Record 50 of Set 1 | ustye
# Processing Record 1 of Set 2 | jamestown
# Processing Record 2 of Set 2 | cidreira
# Processing Record 3 of Set 2 | berlevag
# Processing Record 4 of Set 2 | lorengau
# Processing Record 5 of Set 2 | muskegon
# Processing Record 6 of Set 2 | galveston
# Processing Record 7 of Set 2 | fort nelson
# Processing Record 8 of Set 2 | nioro
# Processing Record 9 of Set 2 | brae
# Processing Record 10 of Set 2 | hami
# Processing Record 11 of Set 2 | port-gentil
# Processing Record 12 of Set 2 | inuvik
# Processing Record 13 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 2 | qaanaaq
# Processing Record 15 of Set 2 | yingkou
# Processing Record 16 of Set 2 | nkhata bay
# Processing Record 17 of Set 2 | jumla
# Processing Record 18 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 2 | lagoa
# Processing Record 20 of Set 2 | kapaa
# Processing Record 21 of Set 2 | sabha
# Processing Record 22 of Set 2 | atbasar
# Processing Record 23 of Set 2 | braganca
# Processing Record 24 of Set 2 | hermanus
# Processing Record 25 of Set 2 | kavieng
# Processing Record 26 of Set 2 | hirara
# Processing Record 27 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 2 | talnakh
# Processing Record 29 of Set 2 | barrow
# Processing Record 30 of Set 2 | severo-kurilsk
# Processing Record 31 of Set 2 | pacific grove
# Processing Record 32 of Set 2 | ghanzi
# Processing Record 33 of Set 2 | rikitea
# Processing Record 34 of Set 2 | viedma
# Processing Record 35 of Set 2 | busselton
# Processing Record 36 of Set 2 | cape town
# Processing Record 37 of Set 2 | zhigansk
# Processing Record 38 of Set 2 | thompson
# Processing Record 39 of Set 2 | charters towers
# Processing Record 40 of Set 2 | jiddah
# City not found. Skipping...
# Processing Record 41 of Set 2 | avarua
# Processing Record 42 of Set 2 | atuona
# Processing Record 43 of Set 2 | hasaki
# Processing Record 44 of Set 2 | jimeta
# Processing Record 45 of Set 2 | paamiut
# Processing Record 46 of Set 2 | kikwit
# Processing Record 47 of Set 2 | punta arenas
# Processing Record 48 of Set 2 | nybro
# Processing Record 49 of Set 2 | touros
# Processing Record 50 of Set 2 | victoria
# Processing Record 1 of Set 3 | ribeira grande
# Processing Record 2 of Set 3 | vao
# Processing Record 3 of Set 3 | port-cartier
# Processing Record 4 of Set 3 | east london
# Processing Record 5 of Set 3 | butaritari
# Processing Record 6 of Set 3 | matara
# Processing Record 7 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 8 of Set 3 | waipawa
# Processing Record 9 of Set 3 | hofn
# Processing Record 10 of Set 3 | yellowknife
# Processing Record 11 of Set 3 | koygorodok
# Processing Record 12 of Set 3 | saskylakh
# Processing Record 13 of Set 3 | shchelyayur
# City not found. Skipping...
# Processing Record 14 of Set 3 | road town
# Processing Record 15 of Set 3 | port alfred
# Processing Record 16 of Set 3 | aksarka
# Processing Record 17 of Set 3 | trincomalee
# Processing Record 18 of Set 3 | vaini
# Processing Record 19 of Set 3 | yuncheng
# Processing Record 20 of Set 3 | bartica
# Processing Record 21 of Set 3 | new norfolk
# Processing Record 22 of Set 3 | kawana waters
# City not found. Skipping...
# Processing Record 23 of Set 3 | abha
# Processing Record 24 of Set 3 | chuy
# Processing Record 25 of Set 3 | sikeston
# Processing Record 26 of Set 3 | xuddur
# Processing Record 27 of Set 3 | flinders
# Processing Record 28 of Set 3 | bredasdorp
# Processing Record 29 of Set 3 | nome
# Processing Record 30 of Set 3 | hithadhoo
# Processing Record 31 of Set 3 | rodrigues alves
# Processing Record 32 of Set 3 | la ronge
# Processing Record 33 of Set 3 | jalu
# Processing Record 34 of Set 3 | ihosy
# Processing Record 35 of Set 3 | port lincoln
# Processing Record 36 of Set 3 | tubuala
# Processing Record 37 of Set 3 | ranong
# Processing Record 38 of Set 3 | saint-philippe
# Processing Record 39 of Set 3 | coos bay
# Processing Record 40 of Set 3 | kiama
# Processing Record 41 of Set 3 | korla
# Processing Record 42 of Set 3 | bay roberts
# Processing Record 43 of Set 3 | bahia blanca
# Processing Record 44 of Set 3 | maniitsoq
# Processing Record 45 of Set 3 | esperance
# Processing Record 46 of Set 3 | college
# Processing Record 47 of Set 3 | le pradet
# Processing Record 48 of Set 3 | manokwari
# Processing Record 49 of Set 3 | makakilo city
# Processing Record 50 of Set 3 | suntar
# Processing Record 1 of Set 4 | saint-georges
# Processing Record 2 of Set 4 | borba
# Processing Record 3 of Set 4 | karratha
# Processing Record 4 of Set 4 | north bend
# Processing Record 5 of Set 4 | hualmay
# Processing Record 6 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 4 | isangel
# Processing Record 8 of Set 4 | norman wells
# Processing Record 9 of Set 4 | vallenar
# Processing Record 10 of Set 4 | latung
# Processing Record 11 of Set 4 | oranjestad
# Processing Record 12 of Set 4 | khatanga
# Processing Record 13 of Set 4 | iqaluit
# Processing Record 14 of Set 4 | katsuura
# Processing Record 15 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 16 of Set 4 | avera
# Processing Record 17 of Set 4 | kemijarvi
# Processing Record 18 of Set 4 | bengkulu
# Processing Record 19 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 4 | armacao dos buzios
# City not found. Skipping...
# Processing Record 21 of Set 4 | sur
# Processing Record 22 of Set 4 | standerton
# Processing Record 23 of Set 4 | point pleasant
# Processing Record 24 of Set 4 | chokurdakh
# Processing Record 25 of Set 4 | yumen
# Processing Record 26 of Set 4 | tarko-sale
# Processing Record 27 of Set 4 | yarmouth
# Processing Record 28 of Set 4 | santander
# Processing Record 29 of Set 4 | red wing
# Processing Record 30 of Set 4 | casma
# Processing Record 31 of Set 4 | klyuchi
# Processing Record 32 of Set 4 | cherskiy
# Processing Record 33 of Set 4 | ancud
# Processing Record 34 of Set 4 | aykhal
# Processing Record 35 of Set 4 | lethem
# Processing Record 36 of Set 4 | hit
# Processing Record 37 of Set 4 | waterfoot
# Processing Record 38 of Set 4 | sogdiondon
# City not found. Skipping...
# Processing Record 39 of Set 4 | carolina
# Processing Record 40 of Set 4 | lompoc
# Processing Record 41 of Set 4 | muchkapskiy
# Processing Record 42 of Set 4 | beboto
# Processing Record 43 of Set 4 | georgetown
# Processing Record 44 of Set 4 | kaeo
# Processing Record 45 of Set 4 | los algarrobos
# Processing Record 46 of Set 4 | oussouye
# Processing Record 47 of Set 4 | lazaro cardenas
# Processing Record 48 of Set 4 | leeton
# Processing Record 49 of Set 4 | linxia
# Processing Record 50 of Set 4 | alofi
# Processing Record 1 of Set 5 | cayenne
# Processing Record 2 of Set 5 | jiuquan
# Processing Record 3 of Set 5 | omsukchan
# Processing Record 4 of Set 5 | bambous virieux
# Processing Record 5 of Set 5 | nikel
# Processing Record 6 of Set 5 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 7 of Set 5 | klaksvik
# Processing Record 8 of Set 5 | zunyi
# Processing Record 9 of Set 5 | longyearbyen
# Processing Record 10 of Set 5 | ponta do sol
# Processing Record 11 of Set 5 | tynda
# Processing Record 12 of Set 5 | manitouwadge
# Processing Record 13 of Set 5 | arlit
# Processing Record 14 of Set 5 | souillac
# Processing Record 15 of Set 5 | zeya
# Processing Record 16 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 17 of Set 5 | jalingo
# Processing Record 18 of Set 5 | zielona gora
# Processing Record 19 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 5 | batagay-alyta
# Processing Record 21 of Set 5 | ambon
# Processing Record 22 of Set 5 | kieta
# Processing Record 23 of Set 5 | asau
# Processing Record 24 of Set 5 | teguldet
# Processing Record 25 of Set 5 | chivilcoy
# Processing Record 26 of Set 5 | cabedelo
# Processing Record 27 of Set 5 | damavand
# Processing Record 28 of Set 5 | broome
# Processing Record 29 of Set 5 | crotone
# Processing Record 30 of Set 5 | luderitz
# Processing Record 31 of Set 5 | naze
# Processing Record 32 of Set 5 | lewiston
# Processing Record 33 of Set 5 | mulege
# Processing Record 34 of Set 5 | dingle
# Processing Record 35 of Set 5 | ca mau
# Processing Record 36 of Set 5 | labuhan
# Processing Record 37 of Set 5 | varberg
# Processing Record 38 of Set 5 | warka
# Processing Record 39 of Set 5 | takoradi
# Processing Record 40 of Set 5 | champerico
# Processing Record 41 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 5 | sauk village
# Processing Record 43 of Set 5 | mollendo
# Processing Record 44 of Set 5 | salalah
# Processing Record 45 of Set 5 | muros
# Processing Record 46 of Set 5 | turukhansk
# Processing Record 47 of Set 5 | hambantota
# Processing Record 48 of Set 5 | poum
# Processing Record 49 of Set 5 | namatanai
# Processing Record 50 of Set 5 | nikolskoye
# Processing Record 1 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 6 | yarim
# Processing Record 3 of Set 6 | pisco
# Processing Record 4 of Set 6 | anadyr
# Processing Record 5 of Set 6 | wanning
# Processing Record 6 of Set 6 | tura
# Processing Record 7 of Set 6 | tongren
# Processing Record 8 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 6 | atambua
# Processing Record 10 of Set 6 | cairns
# Processing Record 11 of Set 6 | saurimo
# Processing Record 12 of Set 6 | hailey
# Processing Record 13 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 14 of Set 6 | vigrestad
# Processing Record 15 of Set 6 | kodiak
# Processing Record 16 of Set 6 | fort saint john
# City not found. Skipping...
# Processing Record 17 of Set 6 | sal rei
# Processing Record 18 of Set 6 | santiago
# Processing Record 19 of Set 6 | almaznyy
# Processing Record 20 of Set 6 | albanel
# Processing Record 21 of Set 6 | la palma
# Processing Record 22 of Set 6 | mount isa
# Processing Record 23 of Set 6 | okha
# Processing Record 24 of Set 6 | la baule-escoublac
# Processing Record 25 of Set 6 | menongue
# Processing Record 26 of Set 6 | vilhena
# Processing Record 27 of Set 6 | bonfim
# Processing Record 28 of Set 6 | oranjemund
# Processing Record 29 of Set 6 | beringovskiy
# Processing Record 30 of Set 6 | vila franca do campo
# Processing Record 31 of Set 6 | tripoli
# Processing Record 32 of Set 6 | lichuan
# Processing Record 33 of Set 6 | lima
# Processing Record 34 of Set 6 | cap malheureux
# Processing Record 35 of Set 6 | dekoa
# City not found. Skipping...
# Processing Record 36 of Set 6 | saint george
# Processing Record 37 of Set 6 | guerrero negro
# Processing Record 38 of Set 6 | mokhsogollokh
# Processing Record 39 of Set 6 | tiarei
# Processing Record 40 of Set 6 | buala
# Processing Record 41 of Set 6 | kodinsk
# Processing Record 42 of Set 6 | waddan
# Processing Record 43 of Set 6 | ilulissat
# Processing Record 44 of Set 6 | kutum
# Processing Record 45 of Set 6 | bar harbor
# Processing Record 46 of Set 6 | ostrovnoy
# Processing Record 47 of Set 6 | pevek
# Processing Record 48 of Set 6 | zemio
# Processing Record 49 of Set 6 | aberdeen
# Processing Record 50 of Set 6 | vesoul
# Processing Record 1 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 3 of Set 7 | puerto escondido
# Processing Record 4 of Set 7 | majene
# Processing Record 5 of Set 7 | omboue
# Processing Record 6 of Set 7 | cabra
# Processing Record 7 of Set 7 | diamantino
# Processing Record 8 of Set 7 | raga
# Processing Record 9 of Set 7 | garissa
# Processing Record 10 of Set 7 | joshimath
# Processing Record 11 of Set 7 | borger
# Processing Record 12 of Set 7 | chitungwiza
# Processing Record 13 of Set 7 | kruisfontein
# Processing Record 14 of Set 7 | moyale
# Processing Record 15 of Set 7 | te anau
# Processing Record 16 of Set 7 | kyabe
# Processing Record 17 of Set 7 | yunjinghong
# City not found. Skipping...
# Processing Record 18 of Set 7 | shache
# Processing Record 19 of Set 7 | havelock
# Processing Record 20 of Set 7 | orlik
# Processing Record 21 of Set 7 | leningradskiy
# Processing Record 22 of Set 7 | maragogi
# Processing Record 23 of Set 7 | buchanan
# Processing Record 24 of Set 7 | torbay
# Processing Record 25 of Set 7 | havoysund
# Processing Record 26 of Set 7 | caruray
# Processing Record 27 of Set 7 | algiers
# Processing Record 28 of Set 7 | sechura
# Processing Record 29 of Set 7 | dothan
# Processing Record 30 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 31 of Set 7 | pyaozerskiy
# Processing Record 32 of Set 7 | vestmannaeyjar
# Processing Record 33 of Set 7 | agirish
# Processing Record 34 of Set 7 | mount gambier
# Processing Record 35 of Set 7 | tasiilaq
# Processing Record 36 of Set 7 | arona
# Processing Record 37 of Set 7 | carnarvon
# Processing Record 38 of Set 7 | sorland
# Processing Record 39 of Set 7 | visby
# Processing Record 40 of Set 7 | maldonado
# Processing Record 41 of Set 7 | saravan
# Processing Record 42 of Set 7 | san juan
# Processing Record 43 of Set 7 | caravelas
# Processing Record 44 of Set 7 | salcininkai
# Processing Record 45 of Set 7 | amazar
# Processing Record 46 of Set 7 | togur
# Processing Record 47 of Set 7 | ardatov
# Processing Record 48 of Set 7 | nemuro
# Processing Record 49 of Set 7 | gornopravdinsk
# Processing Record 50 of Set 7 | bathsheba
# Processing Record 1 of Set 8 | nouakchott
# Processing Record 2 of Set 8 | jutai
# Processing Record 3 of Set 8 | blind river
# Processing Record 4 of Set 8 | kigonsera
# Processing Record 5 of Set 8 | bakel
# Processing Record 6 of Set 8 | ovsyanka
# Processing Record 7 of Set 8 | tactic
# Processing Record 8 of Set 8 | sovetskiy
# Processing Record 9 of Set 8 | leh
# Processing Record 10 of Set 8 | tapaua
# City not found. Skipping...
# Processing Record 11 of Set 8 | jiroft
# City not found. Skipping...
# Processing Record 12 of Set 8 | katangli
# Processing Record 13 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 8 | dikson
# Processing Record 15 of Set 8 | balsas
# Processing Record 16 of Set 8 | kyrksaeterora
# Processing Record 17 of Set 8 | kalabo
# Processing Record 18 of Set 8 | dakar
# Processing Record 19 of Set 8 | tutoia
# Processing Record 20 of Set 8 | nyurba
# Processing Record 21 of Set 8 | bardiyah
# Processing Record 22 of Set 8 | tokur
# Processing Record 23 of Set 8 | kyzyl-suu
# Processing Record 24 of Set 8 | faya
# Processing Record 25 of Set 8 | douglas
# Processing Record 26 of Set 8 | tartus
# Processing Record 27 of Set 8 | bani
# Processing Record 28 of Set 8 | kupino
# Processing Record 29 of Set 8 | eureka
# Processing Record 30 of Set 8 | belen
# Processing Record 31 of Set 8 | xining
# Processing Record 32 of Set 8 | russell
# Processing Record 33 of Set 8 | masingbi
# Processing Record 34 of Set 8 | half moon bay
# Processing Record 35 of Set 8 | boa vista
# Processing Record 36 of Set 8 | copiapo
# Processing Record 37 of Set 8 | dinkelsbuhl
# Processing Record 38 of Set 8 | palmer
# Processing Record 39 of Set 8 | meulaboh
# Processing Record 40 of Set 8 | dobryanka
# Processing Record 41 of Set 8 | fort-shevchenko
# Processing Record 42 of Set 8 | galchino
# City not found. Skipping...
# Processing Record 43 of Set 8 | dubbo
# Processing Record 44 of Set 8 | aguimes
# Processing Record 45 of Set 8 | asfi
# Processing Record 46 of Set 8 | pangkalanbuun
# Processing Record 47 of Set 8 | san quintin
# Processing Record 48 of Set 8 | fevralsk
# City not found. Skipping...
# Processing Record 49 of Set 8 | malanje
# Processing Record 50 of Set 8 | goksun
# Processing Record 1 of Set 9 | porto novo
# Processing Record 2 of Set 9 | coalcoman
# City not found. Skipping...
# Processing Record 3 of Set 9 | huarmey
# Processing Record 4 of Set 9 | fukagawa
# Processing Record 5 of Set 9 | ahuimanu
# Processing Record 6 of Set 9 | bandarbeyla
# Processing Record 7 of Set 9 | sao joao da barra
# Processing Record 8 of Set 9 | karamea
# City not found. Skipping...
# Processing Record 9 of Set 9 | gambiran
# Processing Record 10 of Set 9 | porto santo
# Processing Record 11 of Set 9 | batagay
# Processing Record 12 of Set 9 | high level
# Processing Record 13 of Set 9 | portland
# Processing Record 14 of Set 9 | blonduos
# City not found. Skipping...
# Processing Record 15 of Set 9 | bogovarovo
# Processing Record 16 of Set 9 | kawalu
# Processing Record 17 of Set 9 | merauke
# Processing Record 18 of Set 9 | los llanos de aridane
# Processing Record 19 of Set 9 | bystrzyca klodzka
# Processing Record 20 of Set 9 | port shepstone
# Processing Record 21 of Set 9 | aden
# Processing Record 22 of Set 9 | tuy hoa
# Processing Record 23 of Set 9 | chara
# Processing Record 24 of Set 9 | woodward
# Processing Record 25 of Set 9 | bairiki
# Processing Record 26 of Set 9 | bhum
# Processing Record 27 of Set 9 | rossland
# Processing Record 28 of Set 9 | smithers
# Processing Record 29 of Set 9 | grand gaube
# Processing Record 30 of Set 9 | oistins
# Processing Record 31 of Set 9 | derzhavinsk
# Processing Record 32 of Set 9 | aktau
# Processing Record 33 of Set 9 | wright
# Processing Record 34 of Set 9 | ferkessedougou
# Processing Record 35 of Set 9 | srandakan
# Processing Record 36 of Set 9 | cockburn town
# Processing Record 37 of Set 9 | namibe
# Processing Record 38 of Set 9 | kiunga
# Processing Record 39 of Set 9 | velka bites
# Processing Record 40 of Set 9 | neiafu
# Processing Record 41 of Set 9 | lahat
# Processing Record 42 of Set 9 | samarai
# Processing Record 43 of Set 9 | ballina
# Processing Record 44 of Set 9 | srednekolymsk
# Processing Record 45 of Set 9 | marawi
# Processing Record 46 of Set 9 | diffa
# Processing Record 47 of Set 9 | benguela
# Processing Record 48 of Set 9 | chifeng
# Processing Record 49 of Set 9 | tucuman
# Processing Record 50 of Set 9 | alabaster
# Processing Record 1 of Set 10 | rio gallegos
# Processing Record 2 of Set 10 | riyadh
# Processing Record 3 of Set 10 | honningsvag
# Processing Record 4 of Set 10 | teya
# Processing Record 5 of Set 10 | ouadda
# Processing Record 6 of Set 10 | vila
# Processing Record 7 of Set 10 | pringsewu
# Processing Record 8 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 9 of Set 10 | seoul
# Processing Record 10 of Set 10 | alenquer
# Processing Record 11 of Set 10 | novoagansk
# Processing Record 12 of Set 10 | kottagudem
# Processing Record 13 of Set 10 | carora
# Processing Record 14 of Set 10 | airai
# Processing Record 15 of Set 10 | ijui
# Processing Record 16 of Set 10 | san patricio
# Processing Record 17 of Set 10 | mehamn
# Processing Record 18 of Set 10 | najran
# Processing Record 19 of Set 10 | hay river
# Processing Record 20 of Set 10 | pitea
# Processing Record 21 of Set 10 | kunashak
# Processing Record 22 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 23 of Set 10 | gazli
# Processing Record 24 of Set 10 | nanortalik
# Processing Record 25 of Set 10 | kapit
# Processing Record 26 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 27 of Set 10 | neuquen
# Processing Record 28 of Set 10 | alyangula
# Processing Record 29 of Set 10 | roald
# Processing Record 30 of Set 10 | sao filipe
# Processing Record 31 of Set 10 | salta
# Processing Record 32 of Set 10 | rovaniemi
# Processing Record 33 of Set 10 | tecpan
# Processing Record 34 of Set 10 | chino valley
# Processing Record 35 of Set 10 | hanstholm
# Processing Record 36 of Set 10 | abu zabad
# Processing Record 37 of Set 10 | hovd
# Processing Record 38 of Set 10 | behbahan
# Processing Record 39 of Set 10 | charlottetown
# Processing Record 40 of Set 10 | yulara
# Processing Record 41 of Set 10 | shimoda
# Processing Record 42 of Set 10 | along
# Processing Record 43 of Set 10 | fonte boa
# Processing Record 44 of Set 10 | ossora
# Processing Record 45 of Set 10 | rogaska slatina
# Processing Record 46 of Set 10 | vallehermoso
# Processing Record 47 of Set 10 | marzuq
# Processing Record 48 of Set 10 | henties bay
# Processing Record 49 of Set 10 | aswan
# Processing Record 50 of Set 10 | pangnirtung
# Processing Record 1 of Set 11 | haines junction
# Processing Record 2 of Set 11 | zhezkazgan
# Processing Record 3 of Set 11 | skibbereen
# Processing Record 4 of Set 11 | tir pol
# City not found. Skipping...
# Processing Record 5 of Set 11 | pau brasil
# Processing Record 6 of Set 11 | ust-nera
# Processing Record 7 of Set 11 | vanavara
# Processing Record 8 of Set 11 | boden
# Processing Record 9 of Set 11 | yasothon
# Processing Record 10 of Set 11 | columbus
# Processing Record 11 of Set 11 | zlatoustovsk
# City not found. Skipping...
# Processing Record 12 of Set 11 | lake havasu city
# Processing Record 13 of Set 11 | muskogee
# Processing Record 14 of Set 11 | puerto madryn
# Processing Record 15 of Set 11 | ust-kut
# Processing Record 16 of Set 11 | vardo
# Processing Record 17 of Set 11 | ahipara
# Processing Record 18 of Set 11 | sakakah
# Processing Record 19 of Set 11 | corrente
# Processing Record 20 of Set 11 | bonavista
# Processing Record 21 of Set 11 | saint-joseph
# Processing Record 22 of Set 11 | healdsburg
# Processing Record 23 of Set 11 | narsaq
# Processing Record 24 of Set 11 | port blair
# Processing Record 25 of Set 11 | araouane
# Processing Record 26 of Set 11 | matamoros
# Processing Record 27 of Set 11 | congleton
# Processing Record 28 of Set 11 | pahrump
# Processing Record 29 of Set 11 | anito
# Processing Record 30 of Set 11 | broken hill
# Processing Record 31 of Set 11 | richards bay
# Processing Record 32 of Set 11 | padang
# Processing Record 33 of Set 11 | novikovo
# Processing Record 34 of Set 11 | hoi an
# Processing Record 35 of Set 11 | beirut
# Processing Record 36 of Set 11 | fortuna
# Processing Record 37 of Set 11 | kaitangata
# Processing Record 38 of Set 11 | jiwani
# Processing Record 39 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 40 of Set 11 | nea stira
# Processing Record 41 of Set 11 | rawson
# Processing Record 42 of Set 11 | talara
# Processing Record 43 of Set 11 | cheuskiny
# City not found. Skipping...
# Processing Record 44 of Set 11 | acari
# Processing Record 45 of Set 11 | alice springs
# Processing Record 46 of Set 11 | lalibela
# Processing Record 47 of Set 11 | honavar
# Processing Record 48 of Set 11 | raymond
# Processing Record 49 of Set 11 | arman
# Processing Record 50 of Set 11 | carballo
# Processing Record 1 of Set 12 | pontianak
# Processing Record 2 of Set 12 | udachnyy
# Processing Record 3 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 4 of Set 12 | gat
# Processing Record 5 of Set 12 | rundu
# Processing Record 6 of Set 12 | dunayivtsi
# City not found. Skipping...
# Processing Record 7 of Set 12 | amapa
# Processing Record 8 of Set 12 | northam
# Processing Record 9 of Set 12 | naron
# Processing Record 10 of Set 12 | cuamba
# Processing Record 11 of Set 12 | yatou
# Processing Record 12 of Set 12 | boddam
# Processing Record 13 of Set 12 | muli
# Processing Record 14 of Set 12 | lianran
# Processing Record 15 of Set 12 | mikhaylovka
# Processing Record 16 of Set 12 | gelibolu
# Processing Record 17 of Set 12 | nuuk
# Processing Record 18 of Set 12 | yar-sale
# Processing Record 19 of Set 12 | angoche
# Processing Record 20 of Set 12 | maykor
# Processing Record 21 of Set 12 | oum hadjer
# Processing Record 22 of Set 12 | san cristobal
# Processing Record 23 of Set 12 | mentok
# City not found. Skipping...
# Processing Record 24 of Set 12 | vyartsilya
# Processing Record 25 of Set 12 | kabalo
# Processing Record 26 of Set 12 | toamasina
# Processing Record 27 of Set 12 | nicolet
# Processing Record 28 of Set 12 | rudnichnyy
# Processing Record 29 of Set 12 | zharkovskiy
# Processing Record 30 of Set 12 | abomsa
# Processing Record 31 of Set 12 | sisimiut
# Processing Record 32 of Set 12 | hamilton
# Processing Record 33 of Set 12 | umm kaddadah
# Processing Record 34 of Set 12 | kargasok
# Processing Record 35 of Set 12 | camabatela
# Processing Record 36 of Set 12 | dubti
# Processing Record 37 of Set 12 | saint-francois
# Processing Record 38 of Set 12 | bud
# Processing Record 39 of Set 12 | lata
# Processing Record 40 of Set 12 | tual
# Processing Record 41 of Set 12 | ayr
# Processing Record 42 of Set 12 | pingliang
# Processing Record 43 of Set 12 | hunchun
# Processing Record 44 of Set 12 | ahlat
# Processing Record 45 of Set 12 | kurilsk
# Processing Record 46 of Set 12 | jasper
# Processing Record 47 of Set 12 | mbuji-mayi
# Processing Record 48 of Set 12 | erenhot
# Processing Record 49 of Set 12 | bosaso
# Processing Record 50 of Set 12 | penzance
# Processing Record 1 of Set 13 | pereslavl-zalesskiy
# Processing Record 2 of Set 13 | qandala
# Processing Record 3 of Set 13 | margate
# Processing Record 4 of Set 13 | bandarban
# Processing Record 5 of Set 13 | mudanya
# Processing Record 6 of Set 13 | kamaishi
# Processing Record 7 of Set 13 | taltal
# Processing Record 8 of Set 13 | kavaratti
# Processing Record 9 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 10 of Set 13 | bataipora
# Processing Record 11 of Set 13 | rendsburg
# Processing Record 12 of Set 13 | campbellton
# Processing Record 13 of Set 13 | ponta delgada
# Processing Record 14 of Set 13 | soldatskaya
# Processing Record 15 of Set 13 | ust-kulom
# Processing Record 16 of Set 13 | horki
# Processing Record 17 of Set 13 | krutinka
# Processing Record 18 of Set 13 | safaga
# Processing Record 19 of Set 13 | westport
# Processing Record 20 of Set 13 | sampit
# Processing Record 21 of Set 13 | garmisch-partenkirchen
# Processing Record 22 of Set 13 | muhos
# Processing Record 23 of Set 13 | sangar
# Processing Record 24 of Set 13 | vanino
# Processing Record 25 of Set 13 | tarnalelesz
# Processing Record 26 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 27 of Set 13 | mullaitivu
# City not found. Skipping...
# Processing Record 28 of Set 13 | olavarria
# Processing Record 29 of Set 13 | dunedin
# Processing Record 30 of Set 13 | wagar
# Processing Record 31 of Set 13 | canillo
# Processing Record 32 of Set 13 | camalu
# Processing Record 33 of Set 13 | tornio
# Processing Record 34 of Set 13 | chokwe
# Processing Record 35 of Set 13 | urdzhar
# City not found. Skipping...
# Processing Record 36 of Set 13 | dezful
# Processing Record 37 of Set 13 | reconquista
# Processing Record 38 of Set 13 | acoyapa
# Processing Record 39 of Set 13 | puerto carreno
# Processing Record 40 of Set 13 | gayny
# Processing Record 41 of Set 13 | sarangani
# Processing Record 42 of Set 13 | acapulco
# Processing Record 43 of Set 13 | slave lake
# Processing Record 44 of Set 13 | pleasant point
# Processing Record 45 of Set 13 | zhireken
# Processing Record 46 of Set 13 | chimore
# Processing Record 47 of Set 13 | pombas
# Processing Record 48 of Set 13 | taonan
# Processing Record 49 of Set 13 | evensk
# Processing Record 50 of Set 13 | rosetta
# Processing Record 1 of Set 14 | kinablangan
# Processing Record 2 of Set 14 | shkotovo-22
# City not found. Skipping...
# Processing Record 3 of Set 14 | tucurui
# Processing Record 4 of Set 14 | murray bridge
# Processing Record 5 of Set 14 | surt
# Processing Record 6 of Set 14 | lucea
# Processing Record 7 of Set 14 | sembe
# Processing Record 8 of Set 14 | mildura
# Processing Record 9 of Set 14 | phan thiet
# Processing Record 10 of Set 14 | isoka
# Processing Record 11 of Set 14 | koutsouras
# Processing Record 12 of Set 14 | kultuk
# Processing Record 13 of Set 14 | kudahuvadhoo
# Processing Record 14 of Set 14 | guilin
# Processing Record 15 of Set 14 | chakulia
# Processing Record 16 of Set 14 | salinas
# Processing Record 17 of Set 14 | amahai
# Processing Record 18 of Set 14 | goranboy
# Processing Record 19 of Set 14 | ercis
# Processing Record 20 of Set 14 | mayumba
# Processing Record 21 of Set 14 | ketchikan
# Processing Record 22 of Set 14 | rocha
# Processing Record 23 of Set 14 | saint anthony
# Processing Record 24 of Set 14 | okhotsk
# Processing Record 25 of Set 14 | anjozorobe
# Processing Record 26 of Set 14 | maningrida
# Processing Record 27 of Set 14 | japura
# Processing Record 28 of Set 14 | magadi
# Processing Record 29 of Set 14 | cumaribo
# City not found. Skipping...
# Processing Record 30 of Set 14 | biltine
# Processing Record 31 of Set 14 | kamen-rybolov
# Processing Record 32 of Set 14 | tuatapere
# Processing Record 33 of Set 14 | birjand
# Processing Record 34 of Set 14 | mnogovershinnyy
# Processing Record 35 of Set 14 | tomatlan
# Processing Record 36 of Set 14 | olga
# Processing Record 37 of Set 14 | thunder bay
# Processing Record 38 of Set 14 | plettenberg bay
# Processing Record 39 of Set 14 | vostok
# Processing Record 40 of Set 14 | yanan
# City not found. Skipping...
# Processing Record 41 of Set 14 | laharpur
# Processing Record 42 of Set 14 | comodoro rivadavia
# Processing Record 43 of Set 14 | montrose
# Processing Record 44 of Set 14 | batemans bay
# Processing Record 45 of Set 14 | agadez
# Processing Record 46 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 47 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 48 of Set 14 | sendai
# Processing Record 49 of Set 14 | north augusta
# Processing Record 50 of Set 14 | verkhoyansk
# Processing Record 1 of Set 15 | gollere
# City not found. Skipping...
# Processing Record 2 of Set 15 | krasnoselkup
# Processing Record 3 of Set 15 | lahad datu
# Processing Record 4 of Set 15 | brasilia
# Processing Record 5 of Set 15 | honiara
# Processing Record 6 of Set 15 | phayakkhaphum phisai
# Processing Record 7 of Set 15 | aripuana
# Processing Record 8 of Set 15 | basco
# Processing Record 9 of Set 15 | two rivers
# Processing Record 10 of Set 15 | dawei
# Processing Record 11 of Set 15 | mossendjo
# Processing Record 12 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 15 | hamada
# Processing Record 14 of Set 15 | ishim
# Processing Record 15 of Set 15 | ola
# Processing Record 16 of Set 15 | takapau
# Processing Record 17 of Set 15 | bousso
# Processing Record 18 of Set 15 | laguna
# Processing Record 19 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 20 of Set 15 | augusto correa
# Processing Record 21 of Set 15 | dapaong
# Processing Record 22 of Set 15 | birao
# Processing Record 23 of Set 15 | husum
# Processing Record 24 of Set 15 | chulman
# Processing Record 25 of Set 15 | galiwinku
# City not found. Skipping...
# Processing Record 26 of Set 15 | aklavik
# Processing Record 27 of Set 15 | husavik
# Processing Record 28 of Set 15 | seljord
# Processing Record 29 of Set 15 | thomaston
# Processing Record 30 of Set 15 | forbes
# Processing Record 31 of Set 15 | tompa
# Processing Record 32 of Set 15 | grootfontein
# Processing Record 33 of Set 15 | zapolyarnyy
# Processing Record 34 of Set 15 | saint-pierre
# Processing Record 35 of Set 15 | simao
# Processing Record 36 of Set 15 | ariquemes
# Processing Record 37 of Set 15 | la romana
# Processing Record 38 of Set 15 | bilma
# Processing Record 39 of Set 15 | pareora
# Processing Record 40 of Set 15 | camopi
# Processing Record 41 of Set 15 | port hedland
# Processing Record 42 of Set 15 | dudinka
# Processing Record 43 of Set 15 | sobolevo
# Processing Record 44 of Set 15 | sabratah
# Processing Record 45 of Set 15 | buncrana
# Processing Record 46 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 15 | coahuayana
# Processing Record 48 of Set 15 | istanbul
# Processing Record 49 of Set 15 | carupano
# Processing Record 50 of Set 15 | atasu
# Processing Record 1 of Set 16 | belaya gora
# Processing Record 2 of Set 16 | dalbandin
# Processing Record 3 of Set 16 | segovia
# Processing Record 4 of Set 16 | dandong
# Processing Record 5 of Set 16 | north platte
# Processing Record 6 of Set 16 | urumqi
# Processing Record 7 of Set 16 | sol-iletsk
# Processing Record 8 of Set 16 | kaohsiung
# Processing Record 9 of Set 16 | ust-kuyga
# Processing Record 10 of Set 16 | shirokiy
# Processing Record 11 of Set 16 | moranbah
# Processing Record 12 of Set 16 | carndonagh
# Processing Record 13 of Set 16 | finschhafen
# Processing Record 14 of Set 16 | west wendover
# Processing Record 15 of Set 16 | asamankese
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
 # Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Bilibino  68.0546  166.4372      1.81        86          84
# 1  Puerto Ayora  -0.7393  -90.3518     82.40        74          20
# 2        Ixtapa  20.7000 -105.2000     77.00        69           1
# 3     Williston  48.1470 -103.6180     68.00        18          30
# 4         Praya  14.9215  -23.5087     69.80        78           0
# 5   Provideniya  64.3833 -173.3000      8.60        72          90
# 6         Natal  -5.7950  -35.2094     82.40        74          20
# 7       Ushuaia -54.8000  -68.3000     51.80        58          20
# 8  Constitucion -35.3333  -72.4167     56.17        92          19
# 9      Saldanha -33.0117   17.9442     59.00        82          80
#
#    Wind Speed Country Current Description
# 0        6.67      RU       broken clouds
# 1        6.91      EC          few clouds
# 2       11.50      MX           clear sky
# 3        5.01      US    scattered clouds
# 4       18.41      CV           clear sky
# 5        5.59      RU          light snow
# 6        9.22      BR          few clouds
# 7       13.80      AR          few clouds
# 8        9.91      CL          few clouds
# 9        5.75      ZA       broken clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Bilibino      RU  68.0546  166.4372      1.81        86          84
# 1     Puerto Ayora      EC  -0.7393  -90.3518     82.40        74          20
# 2           Ixtapa      MX  20.7000 -105.2000     77.00        69           1
# 3        Williston      US  48.1470 -103.6180     68.00        18          30
# 4            Praya      CV  14.9215  -23.5087     69.80        78           0
# ..             ...     ...      ...       ...       ...       ...         ...
# 696       Moranbah      AU -22.0016  148.0466     70.84        63           0
# 697     Carndonagh      IE  55.2500   -7.2667     41.05        88           1
# 698    Finschhafen      PG  -6.6024  147.8681     84.29        69          77
# 699  West Wendover      US  40.7391 -114.0733     57.20        17           1
# 700     Asamankese      GH   5.8601   -0.6635     84.20        84          20
#
#      Wind Speed Current Description
# 0          6.67       broken clouds
# 1          6.91          few clouds
# 2         11.50           clear sky
# 3          5.01    scattered clouds
# 4         18.41           clear sky
# ..          ...                 ...
# 696       24.09           clear sky
# 697        2.10           clear sky
# 698        3.44          light rain
# 699        6.91           clear sky
# 700        6.91          few clouds
#
# [701 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
